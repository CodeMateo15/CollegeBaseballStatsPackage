# %%
from ncaa_bbStats import *

print(list_available_years("pitching", "qualified"))
# Out:
# [2021, 2022, 2023, 2024, 2025]

# %%
print(list_players("pitching", "qualified", 2025, "NE"))
# Out:
# ['Aiven Cabral', 'Alessandro Castro', 'Casey Burfield', 'Charlie Walker', 'Drew Christo', 'Jack Bowery', 'Jackson Brockett', 'Jordan Gottesman', 'Maxwell Gitlin', 'Peyton Fosher', 'Ty Horn', 'Will Jones', 'Will Walsh']

# %%
print(player_seasons("pitching", "noMin", "Aiven Cabral"))
print(player_seasons("batting", "noMin", "Jack Goodman"))
# Out:
# [2023, 2024, 2025]
# [2023, 2024, 2025]

# %%
print(get_player_rows("pitching", "noMin", "Aiven Cabral", 2025))
# Out:
# [{'name': 'Aiven Cabral', 'team': 'NE', 'age': 21.0, 'nameascii': 'Aiven Cabral', 'playerid': 'sa3028218', 'mlbamid': 809685.0, 'year': 2025, 'w': 10, 'l': 3, 'era': 2.9216417078718013, 'g': 16, 'gs': 16, 'cg': 1, 'sho': 1, 'sv': 0, 'ip': 89.1, 'tbf': 360, 'h': 78, 'r': 30, 'er': 29, 'hr': 3, 'bb': 14, 'hbp': 7, 'wp': 2, 'bk': 0, 'so': 74, 'k/9': 7.455223668362527, 'bb/9': 1.4104477210415591, 'k/bb': 5.28571429, 'hr/9': 0.3022387973660484, 'k%': 0.20555556, 'bb%': 0.03888889, 'k-bb%': 0.16666667, 'avg': 0.2300885, 'whip': 1.0298507169509798, 'babip': 0.28625954, 'lob%': 0.7278481, 'fip': 3.824366404830174, 'e-f': -0.9027246969583728}]

# %%
print(get_player_rows("batting", "noMin", "Jack Goodman", 2025))
# Out:
# [{'name': 'Jack Goodman', 'team': 'NE', 'age': 21.0, 'nameascii': 'Jack Goodman', 'playerid': 'sa3032460', 'mlbamid': 806275.0, 'year': 2025, 'g': 53, 'ab': 203, 'pa': 234, 'h': 68, '1b': 46, '2b': 11, '3b': 1, 'hr': 10, 'r': 44, 'rbi': 51, 'bb': 26, 'so': 49, 'hbp': 1, 'sf': 4, 'sh': 0, 'gdp': 3, 'sb': 20, 'cs': 9, 'avg': 0.334975369, 'bb%': 0.111111111, 'k%': 0.209401709, 'bb/k': 0.530612244, 'obp': 0.405982905, 'slg': 0.546798029, 'ops': 0.952780934, 'iso': 0.21182266, 'spd': 6.507320696089645, 'babip': 0.391891891, 'wsb': -2.150472437031567, 'wrc': 49.62740297093497, 'wraa': 10.89925924911605, 'woba': 0.4231494474105345, 'wrc+': 128.14299421992578}]

# %%
print(top_players("batting", "hr", 10, 2025))
# Out:
# [{'name': 'Boston Smith', 'team': 'WRST', 'year': 2025, 'value': 26.0}, {'name': 'Mason Neville', 'team': 'ORE', 'year': 2025, 'value': 26.0}, {'name': 'Andrew Fischer', 'team': 'TENN', 'year': 2025, 'value': 25.0}, {'name': 'Matt Schark', 'team': 'SIU', 'year': 2025, 'value': 24.0}, {'name': 'Kyle Fossum', 'team': 'YSU', 'year': 2025, 'value': 23.0}, {'name': 'Roch Cholowsky', 'team': 'UCLA', 'year': 2025, 'value': 23.0}, {'name': 'Cooper Torres', 'team': 'ETSU', 'year': 2025, 'value': 23.0}, {'name': 'Tyler Minick', 'team': 'CONN', 'year': 2025, 'value': 22.0}, {'name': 'Brayden Simpson', 'team': 'HPU', 'year': 2025, 'value': 22.0}, {'name': 'Beau Ankeney', 'team': 'LMU', 'year': 2025, 'value': 22.0}]

# %%
print(batting_stat("Danny Crossen", "ab", "noMin", 2023))
# Out:
# 243.0

# %%
print(pitching_stat("Aiven Cabral", "era", "noMin", 2025))
# Out:
# 2.9216417078718013

# %%
batters = list_batters()
print(batters[:10])
# Out:
# ['A.J. Arnold', 'A.J. Causey', 'A.J. Evasco', 'A.J. Martin', 'A.J. Mendolia', 'A.J. Shaver', 'A.J. Taylor', 'AJ Anderson', 'AJ Anzai', 'AJ Archambo']

# %%
pitchers = list_pitchers()
print(pitchers[:10])
# Out:
# ['A.J. Causey', 'A.J. Colarusso', 'A.J. Pino', 'A.J. Wilson', 'A.J. Winger', 'AC Cabrera', 'AJ Archambo', 'AJ Beltre', 'AJ Blubaugh', 'AJ Camp']
